# %%
import pandas as pd

# %%
df = pd.read_csv('Summary_Tracker.csv')

# %%
df.isnull.Sum().Sum()

# %%
df['Discounts'].fillna(df['Discounts'].mean)

# %%
df.tail(20)

# %%
df.info()

# %%
df.describe()

# %%
print(max(df['Profit']))
print(min(df['Profit']))

# %%
df.shape
