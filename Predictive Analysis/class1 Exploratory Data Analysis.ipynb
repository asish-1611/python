# %%
import pandas as pd

# %%
df = pd.read_csv('Summary_Tracker.csv')

# %%
df.isnull().sum().sum()
# Out:
# np.int64(828)

# %%
df['Discounts'].fillna(df['Discounts'].mean)
# Out:
# 0                                                     0.8
# 1                                                     0.8
# 2       <bound method Series.mean of 0       0.80\n1  ...
# 3       <bound method Series.mean of 0       0.80\n1  ...
# 4       <bound method Series.mean of 0       0.80\n1  ...
#                               ...
# 2318                                                  0.2
# 2319                                                 0.32
# 2320                                                  0.2
# 2321    <bound method Series.mean of 0       0.80\n1  ...
# 2322    <bound method Series.mean of 0       0.80\n1  ...
# Name: Discounts, Length: 2323, dtype: object

# %%
df.tail(20)
# Out:
#       Row ID        Order ID       Ship Mode Customer ID      Customer Name  \
# 2303    9897  CA-2015-156342    Second Class    JF-15415  Jennifer Ferguson
# 2304    9904  CA-2015-122609  Standard Class    DP-13000      Darren Powers
# 2305    9905  CA-2015-122609  Standard Class    DP-13000      Darren Powers
# 2306    9915  CA-2018-160927    Second Class    TM-21010     Tamara Manning
# 2307    9916  CA-2018-160927    Second Class    TM-21010     Tamara Manning
# 2308    9917  CA-2018-160927    Second Class    TM-21010     Tamara Manning
# 2309    9918  CA-2018-160927    Second Class    TM-21010     Tamara Manning
# 2310    9920  CA-2017-149272  Standard Class    MY-18295    Muhammed Yedwab
# 2311    9921  CA-2017-149272  Standard Class    MY-18295    Muhammed Yedwab
# 2312    9923  US-2018-162124  Standard Class    JF-15490       Jeremy Farry
# 2313    9948  CA-2018-121559    Second Class    HW-14935    Helen Wasserman
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2323 entries, 0 to 2322
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         2323 non-null   int64
#  1   Order ID       2323 non-null   object
#  2   Ship Mode      2323 non-null   object
#  3   Customer ID    2323 non-null   object
#  4   Customer Name  2323 non-null   object
#  5   Segment        2323 non-null   object
#  6   Country        2323 non-null   object
#  7   City           2323 non-null   object
#  8   State          2323 non-null   object
#  9   Postal Code    2323 non-null   int64
#  10  Product ID     2323 non-null   object
#  11  Category       2323 non-null   object
#  12  Sub-Category   2323 non-null   object
#  13  Product        2323 non-null   object
#  14  Sales          2323 non-null   float64
#  15  Quantity       2323 non-null   int64
#  16  Profit         2323 non-null   float64
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity       Profit  \
# count  2323.000000   2323.000000   2323.000000  2323.000000  2323.000000
# mean   5030.547998  65340.572536    215.772661     3.779595    17.092709
# std    2923.638538  11427.949045    632.779010     2.160561   291.487465
# min      15.000000  46060.000000      0.444000     1.000000 -3701.892800
# 25%    2564.500000  55125.000000     14.620000     2.000000    -5.664300
# 50%    5029.000000  65203.000000     45.980000     3.000000     5.184000
# 75%    7612.500000  77041.000000    200.012000     5.000000    22.456200
# max    9984.000000  79907.000000  17499.950000    14.000000  8399.976000
#
#         Order Year  Order Month    Order Day    Ship Year   Ship Month  \
# count  2323.000000  2323.000000  2323.000000  2323.000000  2323.000000
# mean   2016.728799     7.692639    15.428325  2016.749462     7.566078
# std       1.126599     3.347807     8.840895     1.132517     3.403310
# ...

# %%
print(max(df['Profit']))
print(min(df['Profit']))
# Out:
# 8399.976
# -3701.8928

# %%
df.shape
# Out:
# (2323, 24)
